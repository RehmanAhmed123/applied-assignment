# %%
Name: Rehman Ahmed
Student ID: 220990081

# %%
import pandas  as pd

# %%
import matplotlib as plt

# %%
data = pd.read_csv("D:\Dell\Desktop\dataset\icesales.csv")

# %%
data
# Out:
#      Temperature C°  Ice Cream Profits per hour
# 0                39                       13.17
# 1                40                       11.88
# 2                41                       18.82
# 3                42                       18.65
# 4                43                       17.02
# ..              ...                         ...
# 360              99                       85.13
# 361              99                       87.08
# 362              99                       89.29
# 363             101                       81.91
# 364             101                       85.02
#
# [365 rows x 2 columns]

# %%
print(data.head())
# Out:
#    Temperature C°  Ice Cream Profits per hour
# 0              39                       13.17
# 1              40                       11.88
# 2              41                       18.82
# 3              42                       18.65
# 4              43                       17.02

# %%
print(data.describe())
# Out:
#        Temperature C°  Ice Cream Profits per hour
# count      365.000000                  365.000000
# mean        71.980822                   52.103616
# std         13.258510                   15.989004
# min         39.000000                   11.880000
# 25%         63.000000                   40.650000
# 50%         73.000000                   53.620000
# 75%         82.000000                   63.630000
# max        101.000000                   89.290000

# %%
print(data.corr())
# Out:
#                             Temperature C°  Ice Cream Profits per hour
# Temperature C°                    1.000000                    0.988446
# Ice Cream Profits per hour        0.988446                    1.000000

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(data['Temperature C°'], data['Ice Cream Profits per hour'], color='blue')
plt.xlabel('Temperature C°')
plt.ylabel('Ice Cream Profits per hour')
plt.title('Temperature C° vs. Ice Cream Profits per hour')
plt.show()

# %%
plt.hist(data['Ice Cream Profits per hour'], bins=10, color='skyblue', edgecolor='black')
plt.xlabel('Temperature C°')
plt.ylabel('Ice Cream Profits per hour')
plt.title('Distribution of Ice Cream Profits')
plt.show()

# %%
data = {
'Temperature': [39, 40, 41, 42, 43, 99, 99, 99, 101, 101],
'Ice Cream Profits': [13.17, 11.88, 18.82, 18.65, 17.02, 85.13, 87.08, 89.29, 81.91, 85.02]
}
df = pd.DataFrame(data)

# %%
import pandas as pd

# Create a DataFrame with some sample data
data = {
    "Temperature C°": [15, 20, 25, 30, 35],
    "Ice Cream Profits per hour": [100, 120, 150, 180, 200]
}
df = pd.DataFrame(data)

# Calculate the correlation coefficient between Temperature and Ice Cream Profits
correlation = df["Temperature C°"].corr(df["Ice Cream Profits per hour"])
print("The correlation between Temperature and Ice Cream Profits per hour:", correlation)
# Out:
# The correlation between Temperature and Ice Cream Profits per hour: 0.9970544855015815

# %%
import seaborn as sns

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', square=True)
plt.title('Correlation Matrix')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(y=df['Ice Cream Profits'], color='lightblue')
plt.title('Boxplot of Ice Cream Profits')
plt.show()

# %%
References:
Introduction and Relational Graphs - Solutions.pdf
